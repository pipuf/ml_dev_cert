# %% [markdown]
# <a href="https://colab.research.google.com/github/pipuf/ml_dev_cert/blob/main/Copy_of_8_1_1_THEORY_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.pipeline import make_pipeline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# %matplotlib notebook
# %matplotlib inline

plt.rcParams['figure.figsize'] = [8, 6]

# %%
# !gdown "1Egv9Q7MnDqPHNO25n-bmGUs4qOcgal4b"

hp = pd.read_csv('house-prices.csv')
hp
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Egv9Q7MnDqPHNO25n-bmGUs4qOcgal4b
# To: /content/house-prices.csv
# 100% 3.87k/3.87k [00:00<00:00, 9.63MB/s]
#      Home   Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood
# 0       1  114300  1790         2          2       2    No         East
# 1       2  114200  2030         4          2       3    No         East
# 2       3  114800  1740         3          2       1    No         East
# 3       4   94700  1980         3          2       3    No         East
# 4       5  119800  2130         3          3       3    No         East
# ..    ...     ...   ...       ...        ...     ...   ...          ...
# 123   124  119700  1900         3          3       3   Yes         East
# 124   125  147900  2160         4          3       3   Yes         East
# 125   126  113500  2070         2          2       2    No        North
# 126   127  149900  2020         3          3       1    No         West
# 127   128  124600  2250         3          3       4    No        North
#
# [128 rows x 8 columns]

# %%
sns.scatterplot(x='SqFt', y='Price', data=hp).set_title('Price vs Square Feet')
# Out:
# Text(0.5, 1.0, 'Price vs Square Feet')

# %% [markdown]
# ## First step: Create train/test splits
#
# - Train set is to fit the model (find the weights)
# - Test set, after the model is trained, evaluate the model on data never seen before

# %%
# Features -> X
X = hp["SqFt"]

# Target labels -> y
y = hp["Price"]

X_train, X_test, y_train, y_test = train_test_split(
  X, y,
  test_size=0.2,
  random_state=3, # we set a specific random_state so that we get the same ("random") partitioning each time
  shuffle=True    # we set shuffle to True so that the data is shuffled randomly before partitioning
)

X_train[0]
# X_train.iloc[0], y_train.iloc[0]
# Out:
# np.int64(1790)

# %%
X.shape
# Out:
# (128,)

# %%
X_train.shape, X_test.shape
# Out:
# ((102,), (26,))

# %%
y_train.shape, y_test.shape
# Out:
# ((102,), (26,))

# %% [markdown]
# ## Create a baseline (naive) model

# %%
class NaiveRegressor():
  """
  This model will compute the median from our
  training dataset and will use that value
  as the predicted value for any given input.

  h(x) = median(train_labels)
  """

  def __init__(self):
    self.w0 = 0
    self.w1 = 0

  def cost(self, X, y):

    # MSE: mean squared error
    diff = (self.predict(X) - y)**2
    m    = len(X)
    diff_sum = sum(diff) / m
    return diff_sum

  def fit(self, X, y):
    self.w0 = np.median(y)

  def predict(self, x):
    return self.w0

# %% [markdown]
# - **fit()** -> trains the model
# - **predict()** -> uses the trained model to get a prediction
# - **transform()** -> uses the trained model to transform data, not used here but common to have it in scalers like MinMaxScaler()

# %%
# Create the regressor model
nv_regressor = NaiveRegressor()

# Calculate cost without training the model
nv_regressor.cost(X=X_train, y=y_train)
# Out:
# 17647522254.901962

# %%
# Predict returns 0 because we dind't train the model yet
# Weights are not set
nv_regressor.predict(1000)
# Out:
# 0

# %%
# Create and train the model
nv_regressor = NaiveRegressor()
nv_regressor.fit(X=X_train, y=y_train) # <- sets w0 to be the median
nv_regressor.cost(X=X_train, y=y_train)
# Out:
# 737499950.9803921

# %%
nv_regressor.predict(250)
# Out:
# np.float64(125950.0)

# %%
nv_regressor.predict(70)
# Out:
# np.float64(125950.0)

# %%
nv_regressor.predict(-100)
# Out:
# np.float64(125950.0)

# %%
sns.scatterplot(x='SqFt', y='Price', data=hp).set_title('Price vs Square Feet')

x1 = hp["SqFt"].min()
x2 = hp["SqFt"].max()
y1 = nv_regressor.predict(x1)
y2 = nv_regressor.predict(x2)
sns.lineplot(x=[x1, x2,], y=[y1, y2,], color='r')
# Out:
# <Axes: title={'center': 'Price vs Square Feet'}, xlabel='SqFt', ylabel='Price'>

# %%
class RandLinearRegressor():
  """
  Linear regression model in which weights are
  chosen by random sampling.
  """

  def __init__(self, max_iter):
    self.w0 = 0
    self.w1 = 0
    self._max_iter = max_iter

  def cost(self, X, y):

    # MSE: mean squared error
    diff = (self.predict(X) - y)**2
    m    = len(X)
    diff_sum = sum(diff) / m
    return diff_sum

  def fit(self, X, y):
    # 1. Iterate over _max_iter
    for i in range(self._max_iter):
      # Get initial cost (MSE)
      initial_cost = self.cost(X, y)

      # Store the previous w0 and w1
      tmp_w0, tmp_w1 = self.w0, self.w1
      # Randomly get a new w0 and w1
      self.w0, self.w1 = np.random.randint(-10000, 10000, 2)

      cost_value = self.cost(X, y)
      if cost_value > initial_cost:
        self.w0, self.w1 = tmp_w0, tmp_w1

  def predict(self, x):
    y = self.w1 * x + self.w0
    return y

# %%
# %%time

# Create and train the model
nv_regressor = RandLinearRegressor(max_iter=10000)

nv_regressor.fit(X=X_train, y=y_train)
# Out:
# CPU times: user 8.83 s, sys: 93.4 ms, total: 8.93 s
# Wall time: 11.7 s

# %%
nv_regressor.w0, nv_regressor.w1
# Out:
# (np.int64(-2998), np.int64(68))

# %%
nv_regressor.predict(20000)
# Out:
# np.int64(1357002)

# %%
sns.scatterplot(x='SqFt', y='Price', data=hp).set_title('Price vs Square Feet')

x1 = hp["SqFt"].min()
x2 = hp["SqFt"].max()
y1 = nv_regressor.predict(x1)
y2 = nv_regressor.predict(x2)
sns.lineplot(x=[x1, x2,], y=[y1, y2,], color='r')
# Out:
# <Axes: title={'center': 'Price vs Square Feet'}, xlabel='SqFt', ylabel='Price'>

# %%
train_cost = nv_regressor.cost(X=X_train, y=y_train)
train_cost
# Out:
# 484291491.0588235

# %%
test_cost = nv_regressor.cost(X=X_test, y=y_test)
test_cost
# Out:
# 583474164.0

# %% [markdown]
# ## Train Linear Regression model on data

# %%
lr1 = SGDRegressor()

# %%
# This will fail bacause we didn't train the model yet
# Weights aren't set at this point
# lr1.coef_, lr1.lr1.intercept_

# %%
# Train model and check weights again
lr1 = SGDRegressor(max_iter=1000, verbose=1, random_state=0)

lr1.fit(X_train.values.reshape(-1, 1), y_train)
# Out:
# -- Epoch 1
# Norm: 1736066268988.77, NNZs: 1, Bias: 7967050715.141273, T: 102, Avg. loss: 54866743753020524902257642176512.000000
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm:
# Total training time: 0.00 seconds.
# -- Epoch 25
# Norm: 1550271001703.67, NNZs: 1, Bias: 11379671254.845430, T: 2550, Avg. loss: 5046547533313953708809083944960.000000
# Total training time: 0.00 seconds.
# -- Epoch 26
# Norm: 1882178882248.99, NNZs: 1, Bias: 14172911308.335258, T: 2652, Avg. loss: 5467536370641011744942596292608.000000
# Total training time: 0.00 seconds.
# -- Epoch 27
# Norm: 2099975623262.58, NNZs: 1, Bias: 11396952362.555172, T: 2754, Avg. loss: 4965732025938576325177533005824.000000
# Total training time: 0.00 seconds.
# -- Epoch 28
# Norm: 180862649494.00, NNZs: 1, Bias: 8643372870.518375, T: 2856, Avg. loss: 4839610576315065836819877724160.000000
# Total training time: 0.01 seconds.
# -- Epoch 29
# Norm: 1414460612526.94, NNZs: 1, Bias: 8641186654.259838, T: 2958, Avg. loss: 5423705235494947453639224983552.000000
# Total training time: 0.01 seconds.
# -- Epoch 30
# Norm: 37135783512.84, NNZs: 1, Bias: 8642626490.428978, T: 3060, Avg. loss: 5005224222316513218998101344256.000000
# Total training time: 0.01 seconds.
# -- Epoch 31
# Norm: 403555133559.02, NNZs: 1, Bias: 8641653534.977711, T: 3162, Avg. loss: 5611565228452135573274975272960.000000
# Total training time: 0.01 seconds.
# -- Epoch 32
# Norm: 2526131502763.02, NNZs: 1, Bias: 5989599627.414127, T: 3264, Avg. loss: 5500357768856491140584948367360.000000
# Total training time: 0.01 seconds.
# -- Epoch 33
# Norm: 972184471334.06, NNZs: 1, Bias: 5995703043.135817, T: 3366, Avg. loss: 5370211073987208333774819426304.000000
# Total training time: 0.01 seconds.
# Convergence after 33 epochs took 0.01 seconds
# SGDRegressor(random_state=0, verbose=1)

# %%
lr1.coef_
# Out:
# array([9.72184471e+11])

# %%
lr1.intercept_
# Out:
# array([5.99570304e+09])

# %% [markdown]
# ### Plot data and trained model

# %%
print(f"Equation: y = {lr1.intercept_[0]:.2f} + {lr1.coef_[0]:.2f}x1")

x1 = X_train.min()
y1 = (lr1.coef_ * x1 + lr1.intercept_)[0]
x2 = X_train.max()
y2 = (lr1.coef_ * x2 + lr1.intercept_)[0]

sns.scatterplot(x=X_train.values, y=y_train).set_title('Price vs Square Feet')
sns.lineplot(x=[x1, x2,], y=[y1, y2,], color='r')
plt.show()
# Out:
# Equation: y = 5995703043.14 + 972184471334.08x1

# %%
lr1.predict([[2400]])
# Out:
# array([2.33324873e+15])

# %% [markdown]
# ## Let's use some Feature Engineering
#
# We will scale our data first in order to help SGD algorithm to converge easier.

# %%
std_scaler = StandardScaler()
# Fit the scaler on train data ONLY!
std_scaler.fit(X_train.values.reshape(-1, 1))
X_train_scaled = std_scaler.transform(X_train.values.reshape(-1, 1))

# Now let's create our model and use the scaled features for training
lr1 = SGDRegressor(verbose=1, random_state=0)
lr1.fit(X_train_scaled, y_train)
# Out:
# -- Epoch 1
# Norm: 7012.82, NNZs: 1, Bias: 44971.685169, T: 102, Avg. loss: 5727733004.044065
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 9289.76, NNZs: 1, Bias: 66593.372067, T: 204, Avg. loss: 3002704039.292192
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 10704.20, NNZs: 1, Bias: 80928.410895, T: 306, Avg. loss: 1835199918.460647
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm:
# Norm: 15498.62, NNZs: 1, Bias: 129646.097908, T: 3264, Avg. loss: 239589688.353219
# Total training time: 0.00 seconds.
# -- Epoch 33
# Norm: 15494.94, NNZs: 1, Bias: 129712.278487, T: 3366, Avg. loss: 239555663.497957
# Total training time: 0.00 seconds.
# -- Epoch 34
# Norm: 15490.56, NNZs: 1, Bias: 129767.301834, T: 3468, Avg. loss: 239532373.699047
# Total training time: 0.00 seconds.
# -- Epoch 35
# Norm: 15495.66, NNZs: 1, Bias: 129824.206363, T: 3570, Avg. loss: 239506826.330160
# Total training time: 0.00 seconds.
# -- Epoch 36
# Norm: 15499.41, NNZs: 1, Bias: 129849.418630, T: 3672, Avg. loss: 239494455.465338
# Total training time: 0.00 seconds.
# -- Epoch 37
# Norm: 15512.10, NNZs: 1, Bias: 129868.245556, T: 3774, Avg. loss: 239483676.926371
# Total training time: 0.00 seconds.
# -- Epoch 38
# Norm: 15532.89, NNZs: 1, Bias: 129902.611734, T: 3876, Avg. loss: 239469322.960105
# Total training time: 0.00 seconds.
# -- Epoch 39
# Norm: 15537.99, NNZs: 1, Bias: 129910.903770, T: 3978, Avg. loss: 239459294.625133
# Total training time: 0.00 seconds.
# -- Epoch 40
# Norm: 15550.59, NNZs: 1, Bias: 129947.161385, T: 4080, Avg. loss: 239451953.064106
# Total training time: 0.00 seconds.
# -- Epoch 41
# Norm: 15552.24, NNZs: 1, Bias: 129974.291659, T: 4182, Avg. loss: 239450990.945212
# Total training time: 0.00 seconds.
# -- Epoch 42
# Norm: 15557.41, NNZs: 1, Bias: 129988.307681, T: 4284, Avg. loss: 239446224.519224
# Total training time: 0.00 seconds.
# -- Epoch 43
# Norm: 15558.71, NNZs: 1, Bias: 129994.317419, T: 4386, Avg. loss: 239442048.569395
# Total training time: 0.00 seconds.
# -- Epoch 44
# Norm: 15543.43, NNZs: 1, Bias: 130003.966388, T: 4488, Avg. loss: 239431507.673502
# Total training time: 0.00 seconds.
# -- Epoch 45
# Norm: 15534.22, NNZs: 1, Bias: 130006.476172, T: 4590, Avg. loss: 239419261.094586
# Total training time: 0.00 seconds.
# -- Epoch 46
# Norm: 15541.73, NNZs: 1, Bias: 130005.471515, T: 4692, Avg. loss: 239427936.523694
# Total training time: 0.00 seconds.
# -- Epoch 47
# Norm: 15535.42, NNZs: 1, Bias: 130005.668576, T: 4794, Avg. loss: 239419137.018681
# Total training time: 0.00 seconds.
# -- Epoch 48
# Norm: 15537.54, NNZs: 1, Bias: 130012.686778, T: 4896, Avg. loss: 239429070.124128
# Total training time: 0.00 seconds.
# -- Epoch 49
# Norm: 15543.14, NNZs: 1, Bias: 130038.796064, T: 4998, Avg. loss: 239413041.163732
# Total training time: 0.00 seconds.
# -- Epoch 50
# Norm: 15533.04, NNZs: 1, Bias: 130045.364353, T: 5100, Avg. loss: 239408414.383387
# Total training time: 0.00 seconds.
# -- Epoch 51
# Norm: 15528.15, NNZs: 1, Bias: 130048.853373, T: 5202, Avg. loss: 239414898.897097
# Total training time: 0.00 seconds.
# -- Epoch 52
# Norm: 15538.13, NNZs: 1, Bias: 130057.290537, T: 5304, Avg. loss: 239406959.700015
# Total training time: 0.00 seconds.
# -- Epoch 53
# Norm: 15543.25, NNZs: 1, Bias: 130049.298213, T: 5406, Avg. loss: 239403009.628928
# Total training time: 0.00 seconds.
# -- Epoch 54
# Norm: 15553.74, NNZs: 1, Bias: 130049.272609, T: 5508, Avg. loss: 239407527.942257
# Total training time: 0.00 seconds.
# -- Epoch 55
# Norm: 15550.15, NNZs: 1, Bias: 130041.173295, T: 5610, Avg. loss: 239400460.718111
# Total training time: 0.00 seconds.
# -- Epoch 56
# Norm: 15539.71, NNZs: 1, Bias: 130052.133804, T: 5712, Avg. loss: 239396096.498388
# Total training time: 0.00 seconds.
# -- Epoch 57
# Norm: 15546.67, NNZs: 1, Bias: 130071.076536, T: 5814, Avg. loss: 239389236.293531
# Total training time: 0.00 seconds.
# -- Epoch 58
# Norm: 15540.15, NNZs: 1, Bias: 130079.183960, T: 5916, Avg. loss: 239396748.479715
# Total training time: 0.00 seconds.
# -- Epoch 59
# Norm: 15550.81, NNZs: 1, Bias: 130093.758664, T: 6018, Avg. loss: 239388895.359706
# Total training time: 0.00 seconds.
# -- Epoch 60
# Norm: 15551.84, NNZs: 1, Bias: 130093.026741, T: 6120, Avg. loss: 239395648.643512
# Total training time: 0.00 seconds.
# -- Epoch 61
# Norm: 15558.12, NNZs: 1, Bias: 130079.580265, T: 6222, Avg. loss: 239377718.672084
# Total training time: 0.00 seconds.
# -- Epoch 62
# Norm: 15561.66, NNZs: 1, Bias: 130083.742800, T: 6324, Avg. loss: 239393327.450844
# Total training time: 0.00 seconds.
# -- Epoch 63
# Norm: 15569.56, NNZs: 1, Bias: 130077.763873, T: 6426, Avg. loss: 239381637.389068
# Total training time: 0.00 seconds.
# -- Epoch 64
# Norm: 15572.92, NNZs: 1, Bias: 130073.645369, T: 6528, Avg. loss: 239384949.543311
# Total training time: 0.00 seconds.
# -- Epoch 65
# Norm: 15572.56, NNZs: 1, Bias: 130075.131186, T: 6630, Avg. loss: 239387669.277419
# Total training time: 0.00 seconds.
# -- Epoch 66
# Norm: 15565.27, NNZs: 1, Bias: 130064.052085, T: 6732, Avg. loss: 239373374.785340
# Total training time: 0.00 seconds.
# -- Epoch 67
# Norm: 15566.11, NNZs: 1, Bias: 130066.602860, T: 6834, Avg. loss: 239382495.175337
# Total training time: 0.00 seconds.
# -- Epoch 68
# Norm: 15560.66, NNZs: 1, Bias: 130066.191880, T: 6936, Avg. loss: 239381984.575115
# Total training time: 0.00 seconds.
# -- Epoch 69
# Norm: 15559.48, NNZs: 1, Bias: 130066.937702, T: 7038, Avg. loss: 239378420.575610
# Total training time: 0.00 seconds.
# -- Epoch 70
# Norm: 15554.88, NNZs: 1, Bias: 130062.172771, T: 7140, Avg. loss: 239372233.647724
# Total training time: 0.00 seconds.
# -- Epoch 71
# Norm: 15554.26, NNZs: 1, Bias: 130072.709396, T: 7242, Avg. loss: 239376289.198922
# Total training time: 0.00 seconds.
# -- Epoch 72
# Norm: 15544.81, NNZs: 1, Bias: 130068.773020, T: 7344, Avg. loss: 239369159.627400
# Total training time: 0.00 seconds.
# -- Epoch 73
# Norm: 15552.49, NNZs: 1, Bias: 130095.089592, T: 7446, Avg. loss: 239345206.930685
# Total training time: 0.00 seconds.
# -- Epoch 74
# Norm: 15552.55, NNZs: 1, Bias: 130107.412893, T: 7548, Avg. loss: 239364156.201558
# Total training time: 0.00 seconds.
# -- Epoch 75
# Norm: 15548.59, NNZs: 1, Bias: 130112.049611, T: 7650, Avg. loss: 239367994.976576
# Total training time: 0.00 seconds.
# -- Epoch 76
# Norm: 15549.48, NNZs: 1, Bias: 130116.008893, T: 7752, Avg. loss: 239366335.185215
# Total training time: 0.00 seconds.
# -- Epoch 77
# Norm: 15548.35, NNZs: 1, Bias: 130105.981448, T: 7854, Avg. loss: 239364254.206840
# Total training time: 0.00 seconds.
# -- Epoch 78
# Norm: 15555.12, NNZs: 1, Bias: 130098.922727, T: 7956, Avg. loss: 239361460.249589
# Total training time: 0.00 seconds.
# Convergence after 78 epochs took 0.00 seconds
# SGDRegressor(random_state=0, verbose=1)

# %%
print(f"Equation: y = {lr1.intercept_[0]:.2f} + {lr1.coef_[0]:.2f}x1")

x1 = X_train_scaled.min()
y1 = (lr1.coef_ * x1 + lr1.intercept_)[0]
x2 = X_train_scaled.max()
y2 = (lr1.coef_ * x2 + lr1.intercept_)[0]

sns.scatterplot(x=X_train_scaled.flatten(), y=y_train).set_title('Price vs Square Feet')
sns.lineplot(x=[x1, x2,], y=[y1, y2,], color='r')
plt.show()
# Out:
# Equation: y = 130098.92 + 15555.12x1

# %%
# Make predictions on train dataset
y_train_pred = lr1.predict(X_train_scaled)
y_train_pred
# Out:
# array([126306.50206224, 150878.08423027, 139645.36095346, 124200.36644784,
#        136135.13492945,  91906.287027  , 117179.91439983, 148069.90341107,
#        125604.45685744, 138241.27054386, 138241.27054386, 111563.55276142,
#        103139.01030381, 141049.45136306, 129816.72808625, 134028.99931505,
#        159302.62668789, 109457.41714702, 137539.22533906, 123498.32124304,
#        110159.46235182,  99628.78427981, 148069.90341107, 122094.23083344,
#        167727.1691455 , 148771.94861587, 137539.22533906,  96820.6034606 ,
#        141049.45136306, 128412.63767664, 122094.23083344, 148069.90341107,
#        134731.04451985, 141049.45136306, 125604.45685744, 159302.62668789,
#        110861.50755662, 121392.18562863, 150176.03902547, 133326.95411025,
#        148069.90341107, 143857.63218226, 134731.04451985, 131220.81849585,
#        129816.72808625, 123498.32124304, 141751.49656786, 127008.54726704,
#        123498.32124304, 123498.32124304, 131220.81849585, 109457.41714702,
#        120690.14042383, 135433.08972465, 105947.19112301, 102436.96509901,
#        139645.36095346, 131220.81849585, 109457.41714702, 112265.59796622,
#        160004.67189269, 129114.68288145, 115073.77878543, 150176.03902547,
#        124902.41165264, 141751.49656786, 145963.76779667, 131922.86370065,
#        133326.95411025, 136135.13492945, 124200.36644784, 120690.14042383,
#        132624.90890545, 144559.67738707, 124200.36644784, 112265.59796622,
#        145261.72259187, 108755.37194222, 124902.41165264, 140347.40615826,
#        130518.77329105, 171939.4403743 , 112265.59796622, 136135.13492945,
#        126306.50206224, 115775.82399023, 161408.76230229, 110861.50755662,
#        125604.45685744, 132624.90890545, 119286.05001423, 122796.27603824,
#        140347.40615826, 124902.41165264, 130518.77329105, 115775.82399023,
#        105947.19112301, 143857.63218226, 129114.68288145, 125604.45685744,
#        145261.72259187, 139645.36095346])

# %%
# Make predictions on test dataset
X_test_scaled = std_scaler.transform(X_test.values.reshape(-1, 1))
y_test_pred = lr1.predict(X_test_scaled)

# %% [markdown]
# ## Linear Regression with two features

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')

x = hp["SqFt"]
y = hp["Bedrooms"]
z = hp["Price"]

ax.set_xlabel("SqFt")
ax.set_ylabel("Bedrooms")
ax.set_zlabel("Price")

ax.scatter(x, y, z)

plt.show()

# %%
# Training code
lr2 = SGDRegressor(random_state=0)

X = hp[["SqFt", "Bedrooms"]].values
y = hp.Price.values

std_scaler = StandardScaler()
X_scaled = std_scaler.fit_transform(X)

lr2.fit(X_scaled, y)
# Out:
# SGDRegressor(random_state=0)

# %%
# Plot code
coefs = lr2.coef_
intercept = lr2.intercept_
num_samples = len(X)

x = X_scaled[:, 0]
y = X_scaled[:, 1]
z = hp.Price.values
xs = np.tile(np.sort(x), (num_samples, 1))
ys = np.tile(np.sort(y), (num_samples, 1)).T
zs = xs*coefs[0] + ys*coefs[1] + intercept
print(f"Equation: y = {intercept[0]:.2f} + {coefs[0]:.2f}x1 + {coefs[1]:.2f}x2")

fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')

ax.set_xlabel("SqFt")
ax.set_ylabel("Bedrooms")
ax.set_zlabel("Price")

ax.scatter(x, y, z)
ax.plot_surface(xs,ys,zs, alpha=0.5, color='r')

plt.show()
# Out:
# Equation: y = 130435.57 + 10414.80x1 + 9039.34x2

# %%
y_pred = lr2.predict(X_scaled)

# %% [markdown]
# ## Regression with Polynomial Features

# %%
# Generate a random dataset
rng = np.random.RandomState(1)
num_samples = 100
x = 10 * rng.rand(num_samples)
x.sort()
y = np.sin(x) + 0.1 * rng.randn(num_samples)

plt.scatter(x, y)

# %%
x_scaled = StandardScaler().fit_transform(x.reshape(-1, 1))

poly_model = make_pipeline(
  PolynomialFeatures(5),
  SGDRegressor(random_state=0)
)
poly_model.fit(x_scaled, y)
yfit = poly_model.predict(x_scaled)

plt.scatter(x_scaled, y)
plt.plot(x_scaled, yfit, color='red')
